# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#imagenes
mj = plt.imread("mj.jpg")
plt.imshow(mj)
plt.show()

# %%
#quitar guias
mj = plt.imread("mj.jpg")
plt.axis("off")
plt.imshow(mj)
plt.show()

# %%
mj = plt.imread("mj.jpg")
plt.imshow(mj[:,:,1], cmap='gray', vmin = 0, vmax = 255,interpolation='none')
plt.show()

# %%
mj = plt.imread("mj.jpg")
plt.imshow(mj[:,:,1], cmap='Purples', vmin = 0, vmax = 255,interpolation='none')
plt.show()

# %%
mj = plt.imread("mj.jpg")
plt.imshow(mj[:,:,1], cmap='Blues', vmin = 0, vmax = 255,interpolation='none')
plt.show()

# %%
mj = plt.imread("mj.jpg")
plt.imshow(mj[:,:,1], cmap='Greens', vmin = 0, vmax = 255,interpolation='none')
plt.show()

# %%
mj = plt.imread("mj.jpg")
plt.imshow(mj[:,:,1], cmap='Oranges', vmin = 0, vmax = 255,interpolation='none')
plt.show()

# %%
mj = plt.imread("mj.jpg")
plt.imshow(mj[:,:,1], cmap='Reds', vmin = 0, vmax = 255,interpolation='none')
plt.show()

# %%
mj = plt.imread("mj.jpg")
plt.imshow(mj[:,:,1], cmap='YlOrRd', vmin = 0, vmax = 255,interpolation='none')
plt.show()

# %%
mj = plt.imread("mj.jpg")
plt.imshow(mj[:,:,1], cmap='YlOrBr', vmin = 0, vmax = 255,interpolation='none')
plt.show()

# %%
mj = plt.imread("mj.jpg")
plt.imshow(mj[:,:,1], cmap='OrRd', vmin = 0, vmax = 255,interpolation='none')
plt.show()

# %%
mj = plt.imread("mj.jpg")
plt.imshow(mj[:,:,1], cmap='PuRd', vmin = 0, vmax = 255,interpolation='none')
plt.show()

# %%
mj = plt.imread("mj.jpg")
plt.imshow(mj[:,:,1], cmap='BuPu', vmin = 0, vmax = 255,interpolation='none')
plt.show()

# %%
mj = plt.imread("mj.jpg")
plt.imshow(mj[:,:,1], cmap='GnBu', vmin = 0, vmax = 255,interpolation='none')
plt.show()

# %%
mj = plt.imread("mj.jpg")
plt.imshow(mj[:,:,1], cmap='PuBu', vmin = 0, vmax = 255,interpolation='none')
plt.show()

# %%
mj = plt.imread("mj.jpg")
plt.imshow(mj[:,:,1], cmap='YlGnBu', vmin = 0, vmax = 255,interpolation='none')
plt.show()

# %%
mj = plt.imread("mj.jpg")
plt.imshow(mj[:,:,1], cmap='PuBuGn', vmin = 0, vmax = 255,interpolation='none')
plt.show()

# %%
mj = plt.imread("mj.jpg")
plt.imshow(mj[:,:,1], cmap='BuGn', vmin = 0, vmax = 255,interpolation='none')
plt.show()

# %%
mj = plt.imread("mj.jpg")
plt.imshow(mj[:,:,1], cmap='YlGn', vmin = 0, vmax = 255,interpolation='none')
plt.show()

# %%
mj = plt.imread("mj.jpg")
plt.imshow(mj[:,:,1], cmap='PiYG', vmin = 0, vmax = 255,interpolation='none')
plt.show()

# %%
mj = plt.imread("mj.jpg")
plt.imshow(mj[:,:,1], cmap='PRGn', vmin = 0, vmax = 255,interpolation='none')
plt.show()

# %%
mj = plt.imread("mj.jpg")
plt.imshow(mj[:,:,1], cmap='BrBG', vmin = 0, vmax = 255,interpolation='none')
plt.show()

# %%
mj = plt.imread("mj.jpg")
plt.imshow(mj[:,:,1], cmap='PuOr', vmin = 0, vmax = 255,interpolation='none')
plt.show()

# %%
mj = plt.imread("mj.jpg")
plt.imshow(mj[:,:,1], cmap='RdGy', vmin = 0, vmax = 255,interpolation='none')
plt.show()

# %%
mj = plt.imread("mj.jpg")
plt.imshow(mj[:,:,1], cmap='RdBu', vmin = 0, vmax = 255,interpolation='none')
plt.show()

# %%
mj = plt.imread("mj.jpg")
plt.imshow(mj[:,:,1], cmap='RdYlBu', vmin = 0, vmax = 255,interpolation='none')
plt.show()

# %%
mj = plt.imread("mj.jpg")
plt.imshow(mj[:,:,1], cmap='RdYlGn', vmin = 0, vmax = 255,interpolation='none')
plt.show()

# %%
mj = plt.imread("mj.jpg")
plt.imshow(mj[:,:,1], cmap='Spectral', vmin = 0, vmax = 255,interpolation='none')
plt.show()

# %%
mj = plt.imread("mj.jpg")
plt.imshow(mj[:,:,1], cmap='coolwarm', vmin = 0, vmax = 255,interpolation='none')
plt.show()

# %%
mj = plt.imread("mj.jpg")
plt.imshow(mj[:,:,1], cmap='bwr', vmin = 0, vmax = 255,interpolation='none')
plt.show()

# %%
mj = plt.imread("mj.jpg")
plt.imshow(mj[:,:,1], cmap='seismic', vmin = 0, vmax = 255,interpolation='none')
plt.show()

# %%
mj = plt.imread("mj.jpg")
plt.imshow(mj[:,:,1], cmap='viridis', vmin = 0, vmax = 255,interpolation='none')
plt.show()

# %%
mj = plt.imread("mj.jpg")
plt.imshow(mj[:,:,1], cmap='plasma', vmin = 0, vmax = 255,interpolation='none')
plt.show()

# %%
mj = plt.imread("mj.jpg")
plt.imshow(mj[:,:,1], cmap='inferno', vmin = 0, vmax = 255,interpolation='none')
plt.show()

# %%
mj = plt.imread("mj.jpg")
plt.imshow(mj[:,:,1], cmap='magma', vmin = 0, vmax = 255,interpolation='none')
plt.show()

# %%
mj = plt.imread("mj.jpg")
plt.imshow(mj[:,:,1], cmap='cividis', vmin = 0, vmax = 255,interpolation='none')
plt.show()

# %%
mj = plt.imread("mj.jpg")
plt.imshow(mj[:,:,1], cmap='twilight', vmin = 0, vmax = 255,interpolation='none')
plt.show()

# %%
mj = plt.imread("mj.jpg")
plt.imshow(mj[:,:,1], cmap='twilight_shifted', vmin = 0, vmax = 255,interpolation='none')
plt.show()

# %%
mj = plt.imread("mj.jpg")
plt.imshow(mj[:,:,1], cmap='hsv', vmin = 0, vmax = 255,interpolation='none')
plt.show()

# %%
mj = plt.imread("mj.jpg")
plt.imshow(mj[:,:,1], cmap='Pastel1', vmin = 0, vmax = 255,interpolation='none')
plt.show()

# %%
mj = plt.imread("mj.jpg")
plt.imshow(mj[:,:,1], cmap='Pastel2', vmin = 0, vmax = 255,interpolation='none')
plt.show()

# %%
mj = plt.imread("mj.jpg")
plt.imshow(mj[:,:,1], cmap='Paired', vmin = 0, vmax = 255,interpolation='none')
plt.show()

# %%
mj = plt.imread("mj.jpg")
plt.imshow(mj[:,:,1], cmap='Accent', vmin = 0, vmax = 255,interpolation='none')
plt.show()

# %%
mj = plt.imread("mj.jpg")
plt.imshow(mj[:,:,1], cmap='Dark2', vmin = 0, vmax = 255,interpolation='none')
plt.show()

# %%
mj = plt.imread("mj.jpg")
plt.imshow(mj[:,:,1], cmap='Set1', vmin = 0, vmax = 255,interpolation='none')
plt.show()

# %%
mj = plt.imread("mj.jpg")
plt.imshow(mj[:,:,1], cmap='Set2', vmin = 0, vmax = 255,interpolation='none')
plt.show()

# %%
mj = plt.imread("mj.jpg")
plt.imshow(mj[:,:,1], cmap='Set3', vmin = 0, vmax = 255,interpolation='none')
plt.show()

# %%
mj = plt.imread("mj.jpg")
plt.imshow(mj[:,:,1], cmap='tab10', vmin = 0, vmax = 255,interpolation='none')
plt.show()

# %%
mj = plt.imread("mj.jpg")
plt.imshow(mj[:,:,1], cmap='tab20', vmin = 0, vmax = 255,interpolation='none')
plt.show()

# %%
mj = plt.imread("mj.jpg")
plt.imshow(mj[:,:,1], cmap='tab20b', vmin = 0, vmax = 255,interpolation='none')
plt.show()

# %%
mj = plt.imread("mj.jpg")
plt.imshow(mj[:,:,1], cmap='tab20c', vmin = 0, vmax = 255,interpolation='none')
plt.show()

# %%
mj = plt.imread("mj.jpg")
plt.imshow(mj[:,:,1], cmap='flag', vmin = 0, vmax = 255,interpolation='none')
plt.show()

# %%
mj = plt.imread("mj.jpg")
plt.imshow(mj[:,:,1], cmap='prism', vmin = 0, vmax = 255,interpolation='none')
plt.show()

# %%
mj = plt.imread("mj.jpg")
plt.imshow(mj[:,:,1], cmap='ocean', vmin = 0, vmax = 255,interpolation='none')
plt.show()

# %%
mj = plt.imread("mj.jpg")
plt.imshow(mj[:,:,1], cmap='gist_earth', vmin = 0, vmax = 255,interpolation='none')
plt.show()

# %%
mj = plt.imread("mj.jpg")
plt.imshow(mj[:,:,1], cmap='terrain', vmin = 0, vmax = 255,interpolation='none')
plt.show()

# %%
mj = plt.imread("mj.jpg")
plt.imshow(mj[:,:,1], cmap='gist_stern', vmin = 0, vmax = 255,interpolation='none')
plt.show()

# %%
mj = plt.imread("mj.jpg")
plt.imshow(mj[:,:,1], cmap='gnuplot', vmin = 0, vmax = 255,interpolation='none')
plt.show()

# %%
mj = plt.imread("mj.jpg")
plt.imshow(mj[:,:,1], cmap='gnuplot2', vmin = 0, vmax = 255,interpolation='none')
plt.show()

# %%
mj = plt.imread("mj.jpg")
plt.imshow(mj[:,:,1], cmap='CMRmap', vmin = 0, vmax = 255,interpolation='none')
plt.show()

# %%
mj = plt.imread("mj.jpg")
plt.imshow(mj[:,:,1], cmap='cubehelix', vmin = 0, vmax = 255,interpolation='none')
plt.show()

# %%
mj = plt.imread("mj.jpg")
plt.imshow(mj[:,:,1], cmap='brg', vmin = 0, vmax = 255,interpolation='none')
plt.show()

# %%
mj = plt.imread("mj.jpg")
plt.imshow(mj[:,:,1], cmap='gist_rainbow', vmin = 0, vmax = 255,interpolation='none')
plt.show()

# %%
mj = plt.imread("mj.jpg")
plt.imshow(mj[:,:,1], cmap='rainbow', vmin = 0, vmax = 255,interpolation='none')
plt.show()

# %%
mj = plt.imread("mj.jpg")
plt.imshow(mj[:,:,1], cmap='jet', vmin = 0, vmax = 255,interpolation='none')
plt.show()

# %%
mj = plt.imread("mj.jpg")
plt.imshow(mj[:,:,1], cmap='turbo', vmin = 0, vmax = 255,interpolation='none')
plt.show()

# %%
mj = plt.imread("mj.jpg")
plt.imshow(mj[:,:,1], cmap='nipy_spectral', vmin = 0, vmax = 255,interpolation='none')
plt.show()

# %%
mj = plt.imread("mj.jpg")
plt.imshow(mj[:,:,1], cmap='gist_ncar', vmin = 0, vmax = 255,interpolation='none')
plt.show()
